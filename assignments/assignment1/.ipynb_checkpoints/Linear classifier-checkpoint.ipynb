# %% [markdown]
# # Задание 1.2 - Линейный классификатор (Linear classifier)
#
# В этом задании мы реализуем другую модель машинного обучения - линейный классификатор. Линейный классификатор подбирает для каждого класса веса, на которые нужно умножить значение каждого признака и потом сложить вместе.
# Тот класс, у которого эта сумма больше, и является предсказанием модели.
#
# В этом задании вы:
# - потренируетесь считать градиенты различных многомерных функций
# - реализуете подсчет градиентов через линейную модель и функцию потерь softmax
# - реализуете процесс тренировки линейного классификатора
# - подберете параметры тренировки на практике
#
# На всякий случай, еще раз ссылка на туториал по numpy:
# http://cs231n.github.io/python-numpy-tutorial/

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
from dataset import load_svhn, random_split_train_val
from gradient_check import check_gradient
from metrics import multiclass_accuracy 
import linear_classifer

# %% [markdown]
# # Как всегда, первым делом загружаем данные
#
# Мы будем использовать все тот же SVHN.

# %%
def prepare_for_linear_classifier(train_X, test_X):
    train_flat = train_X.reshape(train_X.shape[0], -1).astype(np.float) / 255.0
    test_flat = test_X.reshape(test_X.shape[0], -1).astype(np.float) / 255.0
    
    # Subtract mean
    mean_image = np.mean(train_flat, axis = 0)
    train_flat -= mean_image
    test_flat -= mean_image
    
    # Add another channel with ones as a bias term
    train_flat_with_ones = np.hstack([train_flat, np.ones((train_X.shape[0], 1))])
    test_flat_with_ones = np.hstack([test_flat, np.ones((test_X.shape[0], 1))])    
    return train_flat_with_ones, test_flat_with_ones
    
train_X, train_y, test_X, test_y = load_svhn("data", max_train=10000, max_test=1000)    
train_X, test_X = prepare_for_linear_classifier(train_X, test_X)
# Split train into train and val
train_X, train_y, val_X, val_y = random_split_train_val(train_X, train_y, num_val = 1000)

# %% [markdown]
# # Играемся с градиентами!
#
# В этом курсе мы будем писать много функций, которые вычисляют градиенты аналитическим методом.
#
# Все функции, в которых мы будем вычислять градиенты, будут написаны по одной и той же схеме.
# Они будут получать на вход точку, где нужно вычислить значение и градиент функции, а на выходе будут выдавать кортеж (tuple) из двух значений - собственно значения функции в этой точке (всегда одно число) и аналитического значения градиента в той же точке (той же размерности, что и вход).
# ```
# def f(x):
#     """
#     Computes function and analytic gradient at x
#
#     x: np array of float, input to the function
#
#     Returns:
#     value: float, value of the function
#     grad: np array of float, same shape as x
#     """
#     ...
#
#     return value, grad
# ```
#
# Необходимым инструментом во время реализации кода, вычисляющего градиенты, является функция его проверки. Эта функция вычисляет градиент численным методом и сверяет результат с градиентом, вычисленным аналитическим методом.
#
# Мы начнем с того, чтобы реализовать вычисление численного градиента (numeric gradient) в функции `check_gradient` в `gradient_check.py`. Эта функция будет принимать на вход функции формата, заданного выше, использовать значение `value` для вычисления численного градиента и сравнит его с аналитическим - они должны сходиться.
#
# Напишите часть функции, которая вычисляет градиент с помощью численной производной для каждой координаты. Для вычисления производной используйте так называемую two-point formula (https://en.wikipedia.org/wiki/Numerical_differentiation):
#
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/22fc2c0a66c63560a349604f8b6b39221566236d)
#
# Все функции приведенные в следующей клетке должны проходить gradient check.

# %%
# TODO: Implement check_gradient function in gradient_check.py
# All the functions below should pass the gradient check

def square(x):
    return float(x*x), 2*x

check_gradient(square, np.array([3.0]))

def array_sum(x):
    assert x.shape == (2,), x.shape
    return np.sum(x), np.ones_like(x)

check_gradient(array_sum, np.array([3.0, 2.0]))

def array_2d_sum(x):
    assert x.shape == (2,2)
    return np.sum(x), np.ones_like(x)

check_gradient(array_2d_sum, np.array([[3.0, 2.0], [1.0, 0.0]]))
# Out:
# Gradient check passed!
# Gradient check passed!
# Gradient check passed!
# True

# %% [markdown]
# ## Начинаем писать свои функции, считающие аналитический градиент
#
# Теперь реализуем функцию softmax, которая получает на вход оценки для каждого класса и преобразует их в вероятности от 0 до 1:
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/e348290cf48ddbb6e9a6ef4e39363568b67c09d3)
#
# **Важно:** Практический аспект вычисления этой функции заключается в том, что в ней учавствует вычисление экспоненты от потенциально очень больших чисел - это может привести к очень большим значениям в числителе и знаменателе за пределами диапазона float.
#
# К счастью, у этой проблемы есть простое решение -- перед вычислением softmax вычесть из всех оценок максимальное значение среди всех оценок:
# ```
# predictions -= np.max(predictions)
# ```
# (подробнее здесь - http://cs231n.github.io/linear-classify/#softmax, секция `Practical issues: Numeric stability`)

# %%
# TODO Implement softmax and cross-entropy for single sample
probs = linear_classifer.softmax(np.array([-10, 0, 10]))

# Make sure it works for big numbers too!
probs = linear_classifer.softmax(np.array([1000, 0, 0]))
assert np.isclose(probs[0], 1.0)

# %% [markdown]
# Кроме этого, мы реализуем cross-entropy loss, которую мы будем использовать как функцию ошибки (error function).
# В общем виде cross-entropy определена следующим образом:
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/0cb6da032ab424eefdca0884cd4113fe578f4293)
#
# где x - все классы, p(x) - истинная вероятность принадлежности сэмпла классу x, а q(x) - вероятность принадлежности классу x, предсказанная моделью.
# В нашем случае сэмпл принадлежит только одному классу, индекс которого передается функции. Для него p(x) равна 1, а для остальных классов - 0.
#
# Это позволяет реализовать функцию проще!

# %%
probs = linear_classifer.softmax(np.array([-5, 0, 5]))
linear_classifer.cross_entropy_loss(probs, 1)
# Out:
# 5.006760443547122

# %% [markdown]
# После того как мы реализовали сами функции, мы можем реализовать градиент.
#
# Оказывается, что вычисление градиента становится гораздо проще, если объединить эти функции в одну, которая сначала вычисляет вероятности через softmax, а потом использует их для вычисления функции ошибки через cross-entropy loss.
#
# Эта функция `softmax_with_cross_entropy` будет возвращает и значение ошибки, и градиент по входным параметрам. Мы проверим корректность реализации с помощью `check_gradient`.

# %%
# TODO Implement combined function or softmax and cross entropy and produces gradient
loss, grad = linear_classifer.softmax_with_cross_entropy(np.array([1, 0, 0]), 1)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, 1), np.array([1, 0, 0], np.float))
# Out:
# Gradient check passed!
# True

# %% [markdown]
# В качестве метода тренировки мы будем использовать стохастический градиентный спуск (stochastic gradient descent или SGD), который работает с батчами сэмплов.
#
# Поэтому все наши фукнции будут получать не один пример, а батч, то есть входом будет не вектор из `num_classes` оценок, а матрица размерности `batch_size, num_classes`. Индекс примера в батче всегда будет первым измерением.
#
# Следующий шаг - переписать наши функции так, чтобы они поддерживали батчи.
#
# Финальное значение функции ошибки должно остаться числом, и оно равно среднему значению ошибки среди всех примеров в батче.

# %%
# TODO Extend combined function so it can receive a 2d array with batch of samples
np.random.seed(42)
# Test batch_size = 1
num_classes = 4
batch_size = 1
predictions = np.random.randint(-1, 3, size=(batch_size, num_classes)).astype(np.float)
target_index = np.random.randint(0, num_classes, size=(batch_size, 1)).astype(np.int)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, target_index), predictions)

# Test batch_size = 3
num_classes = 4
batch_size = 3
predictions = np.random.randint(-1, 3, size=(batch_size, num_classes)).astype(np.float)
target_index = np.random.randint(0, num_classes, size=(batch_size, 1)).astype(np.int)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, target_index), predictions)

# Make sure maximum subtraction for numberic stability is done separately for every sample in the batch
probs = linear_classifer.softmax(np.array([[20,0,0], [1000, 0, 0]]))
assert np.all(np.isclose(probs[:, 0], 1.0))
# Out:
# Gradient check passed!
# Gradient check passed!

# %% [markdown]
# ### Наконец, реализуем сам линейный классификатор!
#
# softmax и cross-entropy получают на вход оценки, которые выдает линейный классификатор.
#
# Он делает это очень просто: для каждого класса есть набор весов, на которые надо умножить пиксели картинки и сложить. Получившееся число и является оценкой класса, идущей на вход softmax.
#
# Таким образом, линейный классификатор можно представить как умножение вектора с пикселями на матрицу W размера `num_features, num_classes`. Такой подход легко расширяется на случай батча векторов с пикселями X размера `batch_size, num_features`:
#
# `predictions = X * W`, где `*` - матричное умножение.
#
# Реализуйте функцию подсчета линейного классификатора и градиентов по весам `linear_softmax` в файле `linear_classifer.py`

# %%
# TODO Implement linear_softmax function that uses softmax with cross-entropy for linear classifier
batch_size = 2
num_classes = 2
num_features = 3
np.random.seed(42)
W = np.random.randint(-1, 3, size=(num_features, num_classes)).astype(np.float)
X = np.random.randint(-1, 3, size=(batch_size, num_features)).astype(np.float)
target_index = np.ones(batch_size, dtype=np.int)

loss, dW = linear_classifer.linear_softmax(X, W, target_index)
check_gradient(lambda w: linear_classifer.linear_softmax(X, w, target_index), W)
# Out:
# Gradient check passed!
# True

# %% [markdown]
# ### И теперь регуляризация
#
# Мы будем использовать L2 regularization для весов как часть общей функции ошибки.
#
# Напомним, L2 regularization определяется как
#
# l2_reg_loss = regularization_strength * sum<sub>ij</sub> W[i, j]<sup>2</sup>
#
# Реализуйте функцию для его вычисления и вычисления соотвествующих градиентов.

# %%
# TODO Implement l2_regularization function that implements loss for L2 regularization
linear_classifer.l2_regularization(W, 0.01)
check_gradient(lambda w: linear_classifer.l2_regularization(w, 0.01), W)
# Out:
# Gradient check passed!
# True

# %% [markdown]
# # Тренировка!

# %% [markdown]
# Градиенты в порядке, реализуем процесс тренировки!

# %%
# TODO: Implement LinearSoftmaxClassifier.fit function
classifier = linear_classifer.LinearSoftmaxClassifier()
loss_history = classifier.fit(train_X, train_y, epochs=10, learning_rate=1e-3, batch_size=300, reg=1e1)
# Out:
# Epoch 0, loss: 2.398150
# Epoch 1, loss: 2.330538
# Epoch 2, loss: 2.310731
# Epoch 3, loss: 2.304735
# Epoch 4, loss: 2.302688
# Epoch 5, loss: 2.303096
# Epoch 6, loss: 2.301128
# Epoch 7, loss: 2.301751
# Epoch 8, loss: 2.301732
# Epoch 9, loss: 2.301753

# %%
# let's look at the loss history!
plt.plot(loss_history)

# %%
# Let's check how it performs on validation set
pred = classifier.predict(val_X)
accuracy = multiclass_accuracy(pred, val_y)
print("Accuracy: ", accuracy)

# Now, let's train more and see if it performs better
classifier.fit(train_X, train_y, epochs=100, learning_rate=1e-3, batch_size=300, reg=1e1)
pred = classifier.predict(val_X)
accuracy = multiclass_accuracy(pred, val_y)
print("Accuracy after training for 100 epochs: ", accuracy)
# Out:
# Accuracy:  0.12
# Epoch 0, loss: 2.302086
# Epoch 1, loss: 2.301960
# Epoch 2, loss: 2.301735
# Epoch 3, loss: 2.301399
# Epoch 4, loss: 2.302651
# Epoch 5, loss: 2.301416
# Epoch 6, loss: 2.301652
# Epoch 7, loss: 2.301857
# Epoch 8, loss: 2.302088
# Epoch 9, loss: 2.301824
# Epoch 10, loss: 2.302158
# Epoch 11, loss: 2.302596
# Epoch 12, loss: 2.301570
# Epoch 13, loss: 2.301364
# Epoch 14, loss: 2.301830
# Epoch 15, loss: 2.301473
# Epoch 16, loss: 2.301971
# Epoch 17, loss: 2.301372
# Epoch 18, loss: 2.302321
# Epoch 19, loss: 2.302389
# Epoch 20, loss: 2.302152
# Epoch 21, loss: 2.302410
# Epoch 22, loss: 2.301506
# Epoch 23, loss: 2.301886
# Epoch 24, loss: 2.300921
# Epoch 25, loss: 2.301314
# Epoch 26, loss: 2.302504
# Epoch 27, loss: 2.302630
# Epoch 28, loss: 2.302260
# Epoch 29, loss: 2.302012
# Epoch 30, loss: 2.301448
# Epoch 31, loss: 2.302145
# Epoch 32, loss: 2.302753
# Epoch 33, loss: 2.302029
# Epoch 34, loss: 2.301754
# Epoch 35, loss: 2.302427
# Epoch 36, loss: 2.302058
# Epoch 37, loss: 2.302012
# Epoch 38, loss: 2.301463
# Epoch 39, loss: 2.301520
# Epoch 40, loss: 2.302220
# Epoch 41, loss: 2.301699
# Epoch 42, loss: 2.301847
# Epoch 43, loss: 2.302168
# Epoch 44, loss: 2.301476
# Epoch 45, loss: 2.302555
# Epoch 46, loss: 2.301806
# Epoch 47, loss: 2.301184
# Epoch 48, loss: 2.302267
# Epoch 49, loss: 2.302439
# Epoch 50, loss: 2.302529
# Epoch 51, loss: 2.302368
# Epoch 52, loss: 2.301113
# Epoch 53, loss: 2.301374
# Epoch 54, loss: 2.301667
# Epoch 55, loss: 2.302743
# Epoch 56, loss: 2.301844
# Epoch 57, loss: 2.301324
# Epoch 58, loss: 2.302139
# Epoch 59, loss: 2.301704
# Epoch 60, loss: 2.302325
# Epoch 61, loss: 2.303237
# Epoch 62, loss: 2.301942
# Epoch 63, loss: 2.301748
# Epoch 64, loss: 2.301714
# Epoch 65, loss: 2.302879
# Epoch 66, loss: 2.302015
# Epoch 67, loss: 2.302995
# Epoch 68, loss: 2.301838
# Epoch 69, loss: 2.302564
# Epoch 70, loss: 2.301696
# Epoch 71, loss: 2.302858
# Epoch 72, loss: 2.302228
# Epoch 73, loss: 2.301820
# Epoch 74, loss: 2.301769
# Epoch 75, loss: 2.302303
# Epoch 76, loss: 2.302099
# Epoch 77, loss: 2.300878
# Epoch 78, loss: 2.302544
# Epoch 79, loss: 2.301373
# Epoch 80, loss: 2.302640
# Epoch 81, loss: 2.301656
# Epoch 82, loss: 2.302071
# Epoch 83, loss: 2.301643
# Epoch 84, loss: 2.301238
# Epoch 85, loss: 2.302163
# Epoch 86, loss: 2.302037
# Epoch 87, loss: 2.302150
# Epoch 88, loss: 2.302840
# Epoch 89, loss: 2.302431
# Epoch 90, loss: 2.302773
# Epoch 91, loss: 2.302422
# Epoch 92, loss: 2.301626
# Epoch 93, loss: 2.301843
# Epoch 94, loss: 2.302333
# Epoch 95, loss: 2.302229
# Epoch 96, loss: 2.302945
# Epoch 97, loss: 2.301526
# Epoch 98, loss: 2.300950
# Epoch 99, loss: 2.301913
# Accuracy after training for 100 epochs:  0.122

# %% [markdown]
# ### Как и раньше, используем кросс-валидацию для подбора гиперпараметтов.
#
# В этот раз, чтобы тренировка занимала разумное время, мы будем использовать только одно разделение на тренировочные (training) и проверочные (validation) данные.
#
# Теперь нам нужно подобрать не один, а два гиперпараметра! Не ограничивайте себя изначальными значениями в коде.
# Добейтесь точности более чем **20%** на проверочных данных (validation data).

# %%
num_epochs = 200
batch_size = 300

learning_rates = [1e-3, 1e-4, 1e-5]
reg_strengths = [1e-4, 1e-5, 1e-6]

best_classifier = None
best_val_accuracy = None
best_val_accuracy = 0

# TODO use validation set to find the best hyperparameters
# hint: for best results, you might need to try more values for learning rate and regularization strength 
# than provided initially
for rate in learning_rates:
    for reg in reg_strengths:
        loss_history = classifier.fit(train_X, train_y, epochs=100, learning_rate=rate, batch_size=300, reg=reg)
        pred = classifier.predict(val_X)
        accuracy = multiclass_accuracy(pred, val_y)
        if accuracy > best_val_accuracy:
            best_val_accuracy = accuracy
            best_classifier = classifier
            best_loss_history = loss_history
        print("Accuracy after training for 100 epochs: ", accuracy)

print('best validation accuracy achieved: %f' % best_val_accuracy)
# Out:
# Epoch 0, loss: 2.300571
# Epoch 1, loss: 2.299626
# Epoch 2, loss: 2.297989
# Epoch 3, loss: 2.298504
# Epoch 4, loss: 2.298743
# Epoch 5, loss: 2.295584
# Epoch 6, loss: 2.294263
# Epoch 7, loss: 2.295422
# Epoch 8, loss: 2.291634
# Epoch 9, loss: 2.293163
# Epoch 10, loss: 2.289230
# Epoch 11, loss: 2.292963
# Epoch 12, loss: 2.295093
# Epoch 13, loss: 2.291019
# Epoch 14, loss: 2.286344
# Epoch 15, loss: 2.285399
# Epoch 16, loss: 2.289205
# Epoch 17, loss: 2.286664
# Epoch 18, loss: 2.286685
# Epoch 19, loss: 2.285540
# Epoch 20, loss: 2.278718
# Epoch 21, loss: 2.279841
# Epoch 22, loss: 2.277498
# Epoch 23, loss: 2.278767
# Epoch 24, loss: 2.281675
# Epoch 25, loss: 2.283390
# Epoch 26, loss: 2.278791
# Epoch 27, loss: 2.275081
# Epoch 28, loss: 2.276003
# Epoch 29, loss: 2.272120
# Epoch 30, loss: 2.271716
# Epoch 31, loss: 2.275882
# Epoch 32, loss: 2.272606
# Epoch 33, loss: 2.275819
# Epoch 34, loss: 2.276938
# Epoch 35, loss: 2.273619
# Epoch 36, loss: 2.283122
# Epoch 37, loss: 2.267549
# Epoch 38, loss: 2.275072
# Epoch 39, loss: 2.270059
# Epoch 40, loss: 2.272135
# Epoch 41, loss: 2.261819
# Epoch 42, loss: 2.263019
# Epoch 43, loss: 2.265944
# Epoch 44, loss: 2.273795
# Epoch 45, loss: 2.265635
# Epoch 46, loss: 2.264081
# Epoch 47, loss: 2.265428
# Epoch 48, loss: 2.264628
# Epoch 49, loss: 2.267789
# Epoch 50, loss: 2.255734
# Epoch 51, loss: 2.260036
# Epoch 52, loss: 2.260858
# Epoch 53, loss: 2.257520
# Epoch 54, loss: 2.268003
# Epoch 55, loss: 2.274441
# Epoch 56, loss: 2.266961
# Epoch 57, loss: 2.248301
# Epoch 58, loss: 2.261957
# Epoch 59, loss: 2.246790
# Epoch 60, loss: 2.259114
# Epoch 61, loss: 2.269597
# Epoch 62, loss: 2.261617
# Epoch 63, loss: 2.264339
# Epoch 64, loss: 2.263482
# Epoch 65, loss: 2.249557
# Epoch 66, loss: 2.249854
# Epoch 67, loss: 2.266972
# Epoch 68, loss: 2.254004
# Epoch 69, loss: 2.261280
# Epoch 70, loss: 2.239138
# Epoch 71, loss: 2.261668
# Epoch 72, loss: 2.241921
# Epoch 73, loss: 2.250661
# Epoch 74, loss: 2.253465
# Epoch 75, loss: 2.247816
# Epoch 76, loss: 2.251607
# Epoch 77, loss: 2.237561
# Epoch 78, loss: 2.260969
# Epoch 79, loss: 2.231782
# Epoch 80, loss: 2.244392
# Epoch 81, loss: 2.249078
# Epoch 82, loss: 2.242313
# Epoch 83, loss: 2.246337
# Epoch 84, loss: 2.229273
# Epoch 85, loss: 2.242009
# Epoch 86, loss: 2.241790
# Epoch 87, loss: 2.234150
# Epoch 88, loss: 2.236548
# Epoch 89, loss: 2.227074
# Epoch 90, loss: 2.251283
# Epoch 91, loss: 2.219147
# Epoch 92, loss: 2.230659
# Epoch 93, loss: 2.246448
# Epoch 94, loss: 2.250624
# Epoch 95, loss: 2.244273
# Epoch 96, loss: 2.243139
# Epoch 97, loss: 2.223291
# Epoch 98, loss: 2.246616
# Epoch 99, loss: 2.238096
# Accuracy after training for 100 epochs:  0.215
# Epoch 0, loss: 2.236512
# Epoch 1, loss: 2.253918
# Epoch 2, loss: 2.252948
# Epoch 3, loss: 2.239545
# Epoch 4, loss: 2.219120
# Epoch 5, loss: 2.226353
# Epoch 6, loss: 2.229483
# Epoch 7, loss: 2.226210
# Epoch 8, loss: 2.227592
# Epoch 9, loss: 2.221052
# Epoch 10, loss: 2.237606
# Epoch 11, loss: 2.233575
# Epoch 12, loss: 2.243907
# Epoch 13, loss: 2.217730
# Epoch 14, loss: 2.239867
# Epoch 15, loss: 2.239371
# Epoch 16, loss: 2.241733
# Epoch 17, loss: 2.231397
# Epoch 18, loss: 2.221532
# Epoch 19, loss: 2.248928
# Epoch 20, loss: 2.240555
# Epoch 21, loss: 2.223051
# Epoch 22, loss: 2.228844
# Epoch 23, loss: 2.230324
# Epoch 24, loss: 2.241760
# Epoch 25, loss: 2.222526
# Epoch 26, loss: 2.234597
# Epoch 27, loss: 2.223381
# Epoch 28, loss: 2.231459
# Epoch 29, loss: 2.209351
# Epoch 30, loss: 2.211372
# Epoch 31, loss: 2.205805
# Epoch 32, loss: 2.212073
# Epoch 33, loss: 2.210159
# Epoch 34, loss: 2.228583
# Epoch 35, loss: 2.217599
# Epoch 36, loss: 2.214993
# Epoch 37, loss: 2.196858
# Epoch 38, loss: 2.224544
# Epoch 39, loss: 2.213693
# Epoch 40, loss: 2.230177
# Epoch 41, loss: 2.219169
# Epoch 42, loss: 2.214998
# Epoch 43, loss: 2.232676
# Epoch 44, loss: 2.223448
# Epoch 45, loss: 2.223032
# Epoch 46, loss: 2.228586
# Epoch 47, loss: 2.238211
# Epoch 48, loss: 2.209175
# Epoch 49, loss: 2.230167
# Epoch 50, loss: 2.219219
# Epoch 51, loss: 2.211509
# Epoch 52, loss: 2.215096
# Epoch 53, loss: 2.220394
# Epoch 54, loss: 2.229390
# Epoch 55, loss: 2.210160
# Epoch 56, loss: 2.212309
# Epoch 57, loss: 2.212256
# Epoch 58, loss: 2.218658
# Epoch 59, loss: 2.208504
# Epoch 60, loss: 2.235808
# Epoch 61, loss: 2.192995
# Epoch 62, loss: 2.224547
# Epoch 63, loss: 2.196701
# Epoch 64, loss: 2.206618
# Epoch 65, loss: 2.208273
# Epoch 66, loss: 2.222048
# Epoch 67, loss: 2.227832
# Epoch 68, loss: 2.189906
# Epoch 69, loss: 2.215325
# Epoch 70, loss: 2.235348
# Epoch 71, loss: 2.187678
# Epoch 72, loss: 2.225517
# Epoch 73, loss: 2.221562
# Epoch 74, loss: 2.207356
# Epoch 75, loss: 2.224033
# Epoch 76, loss: 2.200753
# Epoch 77, loss: 2.190440
# Epoch 78, loss: 2.229800
# Epoch 79, loss: 2.222298
# Epoch 80, loss: 2.213769
# Epoch 81, loss: 2.230738
# Epoch 82, loss: 2.234357
# Epoch 83, loss: 2.201050
# Epoch 84, loss: 2.204249
# Epoch 85, loss: 2.200856
# Epoch 86, loss: 2.208858
# Epoch 87, loss: 2.198808
# Epoch 88, loss: 2.232767
# Epoch 89, loss: 2.183461
# Epoch 90, loss: 2.203899
# Epoch 91, loss: 2.211435
# Epoch 92, loss: 2.214508
# Epoch 93, loss: 2.210603
# Epoch 94, loss: 2.176963
# Epoch 95, loss: 2.228467
# Epoch 96, loss: 2.185782
# Epoch 97, loss: 2.234111
# Epoch 98, loss: 2.197802
# Epoch 99, loss: 2.191531
# Accuracy after training for 100 epochs:  0.227
# Epoch 0, loss: 2.168866
# Epoch 1, loss: 2.207517
# Epoch 2, loss: 2.200293
# Epoch 3, loss: 2.194890
# Epoch 4, loss: 2.198755
# Epoch 5, loss: 2.204350
# Epoch 6, loss: 2.213415
# Epoch 7, loss: 2.198702
# Epoch 8, loss: 2.173078
# Epoch 9, loss: 2.206363
# Epoch 10, loss: 2.221525
# Epoch 11, loss: 2.186423
# Epoch 12, loss: 2.204812
# Epoch 13, loss: 2.202773
# Epoch 14, loss: 2.173711
# Epoch 15, loss: 2.196158
# Epoch 16, loss: 2.205865
# Epoch 17, loss: 2.203764
# Epoch 18, loss: 2.216920
# Epoch 19, loss: 2.179246
# Epoch 20, loss: 2.216634
# Epoch 21, loss: 2.179199
# Epoch 22, loss: 2.206193
# Epoch 23, loss: 2.206829
# Epoch 24, loss: 2.194904
# Epoch 25, loss: 2.182793
# Epoch 26, loss: 2.220613
# Epoch 27, loss: 2.193937
# Epoch 28, loss: 2.182794
# Epoch 29, loss: 2.170902
# Epoch 30, loss: 2.181278
# Epoch 31, loss: 2.210347
# Epoch 32, loss: 2.183946
# Epoch 33, loss: 2.194469
# Epoch 34, loss: 2.189678
# Epoch 35, loss: 2.199069
# Epoch 36, loss: 2.171469
# Epoch 37, loss: 2.191479
# Epoch 38, loss: 2.203225
# Epoch 39, loss: 2.170561
# Epoch 40, loss: 2.202822
# Epoch 41, loss: 2.187234
# Epoch 42, loss: 2.196136
# Epoch 43, loss: 2.205905
# Epoch 44, loss: 2.155561
# Epoch 45, loss: 2.216150
# Epoch 46, loss: 2.195456
# Epoch 47, loss: 2.166554
# Epoch 48, loss: 2.169667
# Epoch 49, loss: 2.226152
# Epoch 50, loss: 2.148089
# Epoch 51, loss: 2.168452
# Epoch 52, loss: 2.180406
# Epoch 53, loss: 2.184045
# Epoch 54, loss: 2.172930
# Epoch 55, loss: 2.175331
# Epoch 56, loss: 2.168345
# Epoch 57, loss: 2.202907
# Epoch 58, loss: 2.160194
# Epoch 59, loss: 2.194820
# Epoch 60, loss: 2.165528
# Epoch 61, loss: 2.214573
# Epoch 62, loss: 2.181873
# Epoch 63, loss: 2.187325
# Epoch 64, loss: 2.223921
# Epoch 65, loss: 2.183188
# Epoch 66, loss: 2.200648
# Epoch 67, loss: 2.175703
# Epoch 68, loss: 2.154900
# Epoch 69, loss: 2.203228
# Epoch 70, loss: 2.203092
# Epoch 71, loss: 2.201227
# Epoch 72, loss: 2.181158
# Epoch 73, loss: 2.169975
# Epoch 74, loss: 2.187263
# Epoch 75, loss: 2.145393
# Epoch 76, loss: 2.190711
# Epoch 77, loss: 2.170962
# Epoch 78, loss: 2.183808
# Epoch 79, loss: 2.206854
# Epoch 80, loss: 2.210448
# Epoch 81, loss: 2.153783
# Epoch 82, loss: 2.216018
# Epoch 83, loss: 2.210003
# Epoch 84, loss: 2.179878
# Epoch 85, loss: 2.194724
# Epoch 86, loss: 2.147383
# Epoch 87, loss: 2.176796
# Epoch 88, loss: 2.160951
# Epoch 89, loss: 2.191257
# Epoch 90, loss: 2.164341
# Epoch 91, loss: 2.169372
# Epoch 92, loss: 2.182184
# Epoch 93, loss: 2.186349
# Epoch 94, loss: 2.187391
# Epoch 95, loss: 2.177124
# Epoch 96, loss: 2.188189
# Epoch 97, loss: 2.186017
# Epoch 98, loss: 2.181409
# Epoch 99, loss: 2.192987
# Accuracy after training for 100 epochs:  0.225
# Epoch 0, loss: 2.159646
# Epoch 1, loss: 2.176928
# Epoch 2, loss: 2.199020
# Epoch 3, loss: 2.200781
# Epoch 4, loss: 2.233855
# Epoch 5, loss: 2.251350
# Epoch 6, loss: 2.189340
# Epoch 7, loss: 2.166448
# Epoch 8, loss: 2.190959
# Epoch 9, loss: 2.219690
# Epoch 10, loss: 2.230750
# Epoch 11, loss: 2.148718
# Epoch 12, loss: 2.215887
# Epoch 13, loss: 2.192530
# Epoch 14, loss: 2.160511
# Epoch 15, loss: 2.181573
# Epoch 16, loss: 2.227364
# Epoch 17, loss: 2.163507
# Epoch 18, loss: 2.200499
# Epoch 19, loss: 2.176558
# Epoch 20, loss: 2.182980
# Epoch 21, loss: 2.200785
# Epoch 22, loss: 2.143330
# Epoch 23, loss: 2.178449
# Epoch 24, loss: 2.158372
# Epoch 25, loss: 2.202406
# Epoch 26, loss: 2.157556
# Epoch 27, loss: 2.169515
# Epoch 28, loss: 2.193219
# Epoch 29, loss: 2.191557
# Epoch 30, loss: 2.166862
# Epoch 31, loss: 2.198003
# Epoch 32, loss: 2.178793
# Epoch 33, loss: 2.156047
# Epoch 34, loss: 2.192855
# Epoch 35, loss: 2.159608
# Epoch 36, loss: 2.184683
# Epoch 37, loss: 2.184298
# Epoch 38, loss: 2.181925
# Epoch 39, loss: 2.196918
# Epoch 40, loss: 2.177126
# Epoch 41, loss: 2.173140
# Epoch 42, loss: 2.153268
# Epoch 43, loss: 2.146576
# Epoch 44, loss: 2.180782
# Epoch 45, loss: 2.192676
# Epoch 46, loss: 2.160193
# Epoch 47, loss: 2.191955
# Epoch 48, loss: 2.162227
# Epoch 49, loss: 2.187755
# Epoch 50, loss: 2.159221
# Epoch 51, loss: 2.200653
# Epoch 52, loss: 2.175749
# Epoch 53, loss: 2.180723
# Epoch 54, loss: 2.209034
# Epoch 55, loss: 2.161369
# Epoch 56, loss: 2.198753
# Epoch 57, loss: 2.183980
# Epoch 58, loss: 2.246808
# Epoch 59, loss: 2.139195
# Epoch 60, loss: 2.132687
# Epoch 61, loss: 2.192618
# Epoch 62, loss: 2.141910
# Epoch 63, loss: 2.175279
# Epoch 64, loss: 2.141327
# Epoch 65, loss: 2.186058
# Epoch 66, loss: 2.192238
# Epoch 67, loss: 2.181953
# Epoch 68, loss: 2.183592
# Epoch 69, loss: 2.187534
# Epoch 70, loss: 2.177507
# Epoch 71, loss: 2.198218
# Epoch 72, loss: 2.158349
# Epoch 73, loss: 2.171036
# Epoch 74, loss: 2.167238
# Epoch 75, loss: 2.188584
# Epoch 76, loss: 2.158747
# Epoch 77, loss: 2.169978
# Epoch 78, loss: 2.168153
# Epoch 79, loss: 2.191397
# Epoch 80, loss: 2.155039
# Epoch 81, loss: 2.198512
# Epoch 82, loss: 2.204586
# Epoch 83, loss: 2.175924
# Epoch 84, loss: 2.156080
# Epoch 85, loss: 2.180680
# Epoch 86, loss: 2.168530
# Epoch 87, loss: 2.139100
# Epoch 88, loss: 2.142979
# Epoch 89, loss: 2.166956
# Epoch 90, loss: 2.181159
# Epoch 91, loss: 2.175003
# Epoch 92, loss: 2.177153
# Epoch 93, loss: 2.180177
# Epoch 94, loss: 2.183052
# Epoch 95, loss: 2.189642
# Epoch 96, loss: 2.192991
# Epoch 97, loss: 2.187451
# Epoch 98, loss: 2.182110
# Epoch 99, loss: 2.159039
# Accuracy after training for 100 epochs:  0.224
# Epoch 0, loss: 2.209354
# Epoch 1, loss: 2.185469
# Epoch 2, loss: 2.227915
# Epoch 3, loss: 2.214551
# Epoch 4, loss: 2.178880
# Epoch 5, loss: 2.149349
# Epoch 6, loss: 2.214336
# Epoch 7, loss: 2.161816
# Epoch 8, loss: 2.153308
# Epoch 9, loss: 2.189353
# Epoch 10, loss: 2.156811
# Epoch 11, loss: 2.147394
# Epoch 12, loss: 2.184839
# Epoch 13, loss: 2.182075
# Epoch 14, loss: 2.191732
# Epoch 15, loss: 2.205734
# Epoch 16, loss: 2.192437
# Epoch 17, loss: 2.161749
# Epoch 18, loss: 2.167236
# Epoch 19, loss: 2.150398
# Epoch 20, loss: 2.177336
# Epoch 21, loss: 2.145329
# Epoch 22, loss: 2.180827
# Epoch 23, loss: 2.176712
# Epoch 24, loss: 2.204711
# Epoch 25, loss: 2.203755
# Epoch 26, loss: 2.167903
# Epoch 27, loss: 2.170868
# Epoch 28, loss: 2.190708
# Epoch 29, loss: 2.186350
# Epoch 30, loss: 2.185980
# Epoch 31, loss: 2.193461
# Epoch 32, loss: 2.181943
# Epoch 33, loss: 2.125927
# Epoch 34, loss: 2.164907
# Epoch 35, loss: 2.166496
# Epoch 36, loss: 2.182395
# Epoch 37, loss: 2.130593
# Epoch 38, loss: 2.184482
# Epoch 39, loss: 2.198491
# Epoch 40, loss: 2.149407
# Epoch 41, loss: 2.151988
# Epoch 42, loss: 2.190773
# Epoch 43, loss: 2.176299
# Epoch 44, loss: 2.192905
# Epoch 45, loss: 2.175190
# Epoch 46, loss: 2.172343
# Epoch 47, loss: 2.169261
# Epoch 48, loss: 2.165341
# Epoch 49, loss: 2.165102
# Epoch 50, loss: 2.171552
# Epoch 51, loss: 2.154080
# Epoch 52, loss: 2.221268
# Epoch 53, loss: 2.195530
# Epoch 54, loss: 2.143003
# Epoch 55, loss: 2.178383
# Epoch 56, loss: 2.200482
# Epoch 57, loss: 2.188257
# Epoch 58, loss: 2.198113
# Epoch 59, loss: 2.152713
# Epoch 60, loss: 2.191248
# Epoch 61, loss: 2.193191
# Epoch 62, loss: 2.194733
# Epoch 63, loss: 2.157991
# Epoch 64, loss: 2.167473
# Epoch 65, loss: 2.163221
# Epoch 66, loss: 2.147951
# Epoch 67, loss: 2.158327
# Epoch 68, loss: 2.195737
# Epoch 69, loss: 2.217543
# Epoch 70, loss: 2.142082
# Epoch 71, loss: 2.184575
# Epoch 72, loss: 2.157508
# Epoch 73, loss: 2.160715
# Epoch 74, loss: 2.176025
# Epoch 75, loss: 2.166216
# Epoch 76, loss: 2.182662
# Epoch 77, loss: 2.168149
# Epoch 78, loss: 2.190914
# Epoch 79, loss: 2.136169
# Epoch 80, loss: 2.157458
# Epoch 81, loss: 2.220192
# Epoch 82, loss: 2.153748
# Epoch 83, loss: 2.190352
# Epoch 84, loss: 2.116283
# Epoch 85, loss: 2.165477
# Epoch 86, loss: 2.149254
# Epoch 87, loss: 2.176384
# Epoch 88, loss: 2.162349
# Epoch 89, loss: 2.137346
# Epoch 90, loss: 2.144095
# Epoch 91, loss: 2.194856
# Epoch 92, loss: 2.184321
# Epoch 93, loss: 2.190294
# Epoch 94, loss: 2.186354
# Epoch 95, loss: 2.186800
# Epoch 96, loss: 2.185644
# Epoch 97, loss: 2.175622
# Epoch 98, loss: 2.194782
# Epoch 99, loss: 2.213352
# Accuracy after training for 100 epochs:  0.225
# Epoch 0, loss: 2.173507
# Epoch 1, loss: 2.190132
# Epoch 2, loss: 2.146956
# Epoch 3, loss: 2.184833
# Epoch 4, loss: 2.204419
# Epoch 5, loss: 2.157425
# Epoch 6, loss: 2.164448
# Epoch 7, loss: 2.194291
# Epoch 8, loss: 2.165175
# Epoch 9, loss: 2.154815
# Epoch 10, loss: 2.150950
# Epoch 11, loss: 2.173621
# Epoch 12, loss: 2.181862
# Epoch 13, loss: 2.170521
# Epoch 14, loss: 2.207033
# Epoch 15, loss: 2.159093
# Epoch 16, loss: 2.162576
# Epoch 17, loss: 2.203396
# Epoch 18, loss: 2.199758
# Epoch 19, loss: 2.182020
# Epoch 20, loss: 2.133702
# Epoch 21, loss: 2.179768
# Epoch 22, loss: 2.171890
# Epoch 23, loss: 2.138886
# Epoch 24, loss: 2.199463
# Epoch 25, loss: 2.176031
# Epoch 26, loss: 2.172297
# Epoch 27, loss: 2.172824
# Epoch 28, loss: 2.145833
# Epoch 29, loss: 2.166603
# Epoch 30, loss: 2.161410
# Epoch 31, loss: 2.171993
# Epoch 32, loss: 2.182805
# Epoch 33, loss: 2.163278
# Epoch 34, loss: 2.214084
# Epoch 35, loss: 2.195652
# Epoch 36, loss: 2.157343
# Epoch 37, loss: 2.206808
# Epoch 38, loss: 2.164586
# Epoch 39, loss: 2.162163
# Epoch 40, loss: 2.167126
# Epoch 41, loss: 2.230939
# Epoch 42, loss: 2.190392
# Epoch 43, loss: 2.185352
# Epoch 44, loss: 2.150519
# Epoch 45, loss: 2.155934
# Epoch 46, loss: 2.187199
# Epoch 47, loss: 2.167343
# Epoch 48, loss: 2.135684
# Epoch 49, loss: 2.179146
# Epoch 50, loss: 2.166134
# Epoch 51, loss: 2.170306
# Epoch 52, loss: 2.155446
# Epoch 53, loss: 2.198619
# Epoch 54, loss: 2.194386
# Epoch 55, loss: 2.187743
# Epoch 56, loss: 2.175251
# Epoch 57, loss: 2.161261
# Epoch 58, loss: 2.207092
# Epoch 59, loss: 2.193423
# Epoch 60, loss: 2.202270
# Epoch 61, loss: 2.190144
# Epoch 62, loss: 2.163958
# Epoch 63, loss: 2.226907
# Epoch 64, loss: 2.186811
# Epoch 65, loss: 2.138578
# Epoch 66, loss: 2.202293
# Epoch 67, loss: 2.158447
# Epoch 68, loss: 2.181757
# Epoch 69, loss: 2.163537
# Epoch 70, loss: 2.167145
# Epoch 71, loss: 2.166050
# Epoch 72, loss: 2.175354
# Epoch 73, loss: 2.191516
# Epoch 74, loss: 2.171429
# Epoch 75, loss: 2.194109
# Epoch 76, loss: 2.196365
# Epoch 77, loss: 2.161920
# Epoch 78, loss: 2.156712
# Epoch 79, loss: 2.185314
# Epoch 80, loss: 2.163372
# Epoch 81, loss: 2.176297
# Epoch 82, loss: 2.146598
# Epoch 83, loss: 2.205532
# Epoch 84, loss: 2.192994
# Epoch 85, loss: 2.164263
# Epoch 86, loss: 2.166774
# Epoch 87, loss: 2.187364
# Epoch 88, loss: 2.195845
# Epoch 89, loss: 2.186337
# Epoch 90, loss: 2.177691
# Epoch 91, loss: 2.178464
# Epoch 92, loss: 2.173078
# Epoch 93, loss: 2.177698
# Epoch 94, loss: 2.180902
# Epoch 95, loss: 2.191199
# Epoch 96, loss: 2.161153
# Epoch 97, loss: 2.151677
# Epoch 98, loss: 2.203487
# Epoch 99, loss: 2.203136
# Accuracy after training for 100 epochs:  0.226
# Epoch 0, loss: 2.168278
# Epoch 1, loss: 2.209129
# Epoch 2, loss: 2.184210
# Epoch 3, loss: 2.167722
# Epoch 4, loss: 2.176074
# Epoch 5, loss: 2.198361
# Epoch 6, loss: 2.146108
# Epoch 7, loss: 2.159957
# Epoch 8, loss: 2.181177
# Epoch 9, loss: 2.178456
# Epoch 10, loss: 2.130901
# Epoch 11, loss: 2.201227
# Epoch 12, loss: 2.175362
# Epoch 13, loss: 2.158129
# Epoch 14, loss: 2.177570
# Epoch 15, loss: 2.137113
# Epoch 16, loss: 2.143333
# Epoch 17, loss: 2.177933
# Epoch 18, loss: 2.167109
# Epoch 19, loss: 2.191890
# Epoch 20, loss: 2.178047
# Epoch 21, loss: 2.182620
# Epoch 22, loss: 2.168580
# Epoch 23, loss: 2.149516
# Epoch 24, loss: 2.172336
# Epoch 25, loss: 2.187857
# Epoch 26, loss: 2.204095
# Epoch 27, loss: 2.172114
# Epoch 28, loss: 2.212420
# Epoch 29, loss: 2.182638
# Epoch 30, loss: 2.165228
# Epoch 31, loss: 2.196210
# Epoch 32, loss: 2.172340
# Epoch 33, loss: 2.171358
# Epoch 34, loss: 2.184206
# Epoch 35, loss: 2.183450
# Epoch 36, loss: 2.190093
# Epoch 37, loss: 2.172762
# Epoch 38, loss: 2.183498
# Epoch 39, loss: 2.162918
# Epoch 40, loss: 2.205738
# Epoch 41, loss: 2.203336
# Epoch 42, loss: 2.177888
# Epoch 43, loss: 2.224964
# Epoch 44, loss: 2.191704
# Epoch 45, loss: 2.163488
# Epoch 46, loss: 2.168752
# Epoch 47, loss: 2.215109
# Epoch 48, loss: 2.127101
# Epoch 49, loss: 2.170262
# Epoch 50, loss: 2.176089
# Epoch 51, loss: 2.188306
# Epoch 52, loss: 2.173530
# Epoch 53, loss: 2.175698
# Epoch 54, loss: 2.181085
# Epoch 55, loss: 2.161902
# Epoch 56, loss: 2.155940
# Epoch 57, loss: 2.165172
# Epoch 58, loss: 2.181111
# Epoch 59, loss: 2.182783
# Epoch 60, loss: 2.182898
# Epoch 61, loss: 2.158137
# Epoch 62, loss: 2.181834
# Epoch 63, loss: 2.150172
# Epoch 64, loss: 2.173700
# Epoch 65, loss: 2.174237
# Epoch 66, loss: 2.183735
# Epoch 67, loss: 2.183116
# Epoch 68, loss: 2.190375
# Epoch 69, loss: 2.165352
# Epoch 70, loss: 2.218621
# Epoch 71, loss: 2.208211
# Epoch 72, loss: 2.169777
# Epoch 73, loss: 2.171939
# Epoch 74, loss: 2.153725
# Epoch 75, loss: 2.146538
# Epoch 76, loss: 2.166904
# Epoch 77, loss: 2.184516
# Epoch 78, loss: 2.200909
# Epoch 79, loss: 2.182485
# Epoch 80, loss: 2.201171
# Epoch 81, loss: 2.174688
# Epoch 82, loss: 2.167752
# Epoch 83, loss: 2.157006
# Epoch 84, loss: 2.148500
# Epoch 85, loss: 2.160701
# Epoch 86, loss: 2.172212
# Epoch 87, loss: 2.148651
# Epoch 88, loss: 2.218453
# Epoch 89, loss: 2.215043
# Epoch 90, loss: 2.204691
# Epoch 91, loss: 2.201432
# Epoch 92, loss: 2.160350
# Epoch 93, loss: 2.128940
# Epoch 94, loss: 2.196883
# Epoch 95, loss: 2.236582
# Epoch 96, loss: 2.189624
# Epoch 97, loss: 2.154996
# Epoch 98, loss: 2.173469
# Epoch 99, loss: 2.161039
# Accuracy after training for 100 epochs:  0.226
# Epoch 0, loss: 2.224423
# Epoch 1, loss: 2.179415
# Epoch 2, loss: 2.213528
# Epoch 3, loss: 2.205107
# Epoch 4, loss: 2.222947
# Epoch 5, loss: 2.172029
# Epoch 6, loss: 2.156920
# Epoch 7, loss: 2.167943
# Epoch 8, loss: 2.168932
# Epoch 9, loss: 2.194666
# Epoch 10, loss: 2.189177
# Epoch 11, loss: 2.199643
# Epoch 12, loss: 2.188106
# Epoch 13, loss: 2.154413
# Epoch 14, loss: 2.205853
# Epoch 15, loss: 2.201445
# Epoch 16, loss: 2.202881
# Epoch 17, loss: 2.140876
# Epoch 18, loss: 2.168624
# Epoch 19, loss: 2.130830
# Epoch 20, loss: 2.138390
# Epoch 21, loss: 2.182922
# Epoch 22, loss: 2.188941
# Epoch 23, loss: 2.173574
# Epoch 24, loss: 2.226193
# Epoch 25, loss: 2.136652
# Epoch 26, loss: 2.190846
# Epoch 27, loss: 2.167407
# Epoch 28, loss: 2.157679
# Epoch 29, loss: 2.148040
# Epoch 30, loss: 2.196292
# Epoch 31, loss: 2.155478
# Epoch 32, loss: 2.148878
# Epoch 33, loss: 2.161468
# Epoch 34, loss: 2.150407
# Epoch 35, loss: 2.168564
# Epoch 36, loss: 2.166483
# Epoch 37, loss: 2.201202
# Epoch 38, loss: 2.177986
# Epoch 39, loss: 2.159003
# Epoch 40, loss: 2.172904
# Epoch 41, loss: 2.201447
# Epoch 42, loss: 2.159060
# Epoch 43, loss: 2.188388
# Epoch 44, loss: 2.182716
# Epoch 45, loss: 2.187194
# Epoch 46, loss: 2.169253
# Epoch 47, loss: 2.126421
# Epoch 48, loss: 2.180869
# Epoch 49, loss: 2.138339
# Epoch 50, loss: 2.131594
# Epoch 51, loss: 2.140465
# Epoch 52, loss: 2.143523
# Epoch 53, loss: 2.178535
# Epoch 54, loss: 2.162301
# Epoch 55, loss: 2.172051
# Epoch 56, loss: 2.148133
# Epoch 57, loss: 2.179171
# Epoch 58, loss: 2.177564
# Epoch 59, loss: 2.188703
# Epoch 60, loss: 2.176458
# Epoch 61, loss: 2.182035
# Epoch 62, loss: 2.168027
# Epoch 63, loss: 2.182132
# Epoch 64, loss: 2.175608
# Epoch 65, loss: 2.140786
# Epoch 66, loss: 2.163854
# Epoch 67, loss: 2.170141
# Epoch 68, loss: 2.177564
# Epoch 69, loss: 2.197084
# Epoch 70, loss: 2.167844
# Epoch 71, loss: 2.182848
# Epoch 72, loss: 2.181342
# Epoch 73, loss: 2.188494
# Epoch 74, loss: 2.157819
# Epoch 75, loss: 2.193022
# Epoch 76, loss: 2.209401
# Epoch 77, loss: 2.204621
# Epoch 78, loss: 2.190705
# Epoch 79, loss: 2.171026
# Epoch 80, loss: 2.175328
# Epoch 81, loss: 2.150043
# Epoch 82, loss: 2.179322
# Epoch 83, loss: 2.164610
# Epoch 84, loss: 2.171419
# Epoch 85, loss: 2.120812
# Epoch 86, loss: 2.162379
# Epoch 87, loss: 2.145974
# Epoch 88, loss: 2.173719
# Epoch 89, loss: 2.203919
# Epoch 90, loss: 2.190600
# Epoch 91, loss: 2.167849
# Epoch 92, loss: 2.169721
# Epoch 93, loss: 2.170297
# Epoch 94, loss: 2.161878
# Epoch 95, loss: 2.191501
# Epoch 96, loss: 2.208700
# Epoch 97, loss: 2.168102
# Epoch 98, loss: 2.158660
# Epoch 99, loss: 2.180729
# Accuracy after training for 100 epochs:  0.226
# Epoch 0, loss: 2.171584
# Epoch 1, loss: 2.144084
# Epoch 2, loss: 2.151817
# Epoch 3, loss: 2.171687
# Epoch 4, loss: 2.211558
# Epoch 5, loss: 2.183230
# Epoch 6, loss: 2.163124
# Epoch 7, loss: 2.172166
# Epoch 8, loss: 2.175794
# Epoch 9, loss: 2.200844
# Epoch 10, loss: 2.193603
# Epoch 11, loss: 2.170266
# Epoch 12, loss: 2.160941
# Epoch 13, loss: 2.180299
# Epoch 14, loss: 2.139218
# Epoch 15, loss: 2.213344
# Epoch 16, loss: 2.165455
# Epoch 17, loss: 2.159881
# Epoch 18, loss: 2.179458
# Epoch 19, loss: 2.160318
# Epoch 20, loss: 2.198239
# Epoch 21, loss: 2.191656
# Epoch 22, loss: 2.184565
# Epoch 23, loss: 2.191966
# Epoch 24, loss: 2.157135
# Epoch 25, loss: 2.166327
# Epoch 26, loss: 2.219884
# Epoch 27, loss: 2.159253
# Epoch 28, loss: 2.161822
# Epoch 29, loss: 2.171880
# Epoch 30, loss: 2.183378
# Epoch 31, loss: 2.181784
# Epoch 32, loss: 2.153450
# Epoch 33, loss: 2.145512
# Epoch 34, loss: 2.158202
# Epoch 35, loss: 2.175478
# Epoch 36, loss: 2.150220
# Epoch 37, loss: 2.175799
# Epoch 38, loss: 2.129686
# Epoch 39, loss: 2.155653
# Epoch 40, loss: 2.186738
# Epoch 41, loss: 2.170074
# Epoch 42, loss: 2.170648
# Epoch 43, loss: 2.154673
# Epoch 44, loss: 2.174911
# Epoch 45, loss: 2.182455
# Epoch 46, loss: 2.156439
# Epoch 47, loss: 2.192140
# Epoch 48, loss: 2.172853
# Epoch 49, loss: 2.186938
# Epoch 50, loss: 2.159852
# Epoch 51, loss: 2.153804
# Epoch 52, loss: 2.176322
# Epoch 53, loss: 2.189950
# Epoch 54, loss: 2.164602
# Epoch 55, loss: 2.198179
# Epoch 56, loss: 2.155509
# Epoch 57, loss: 2.139532
# Epoch 58, loss: 2.187624
# Epoch 59, loss: 2.171252
# Epoch 60, loss: 2.189165
# Epoch 61, loss: 2.173554
# Epoch 62, loss: 2.155580
# Epoch 63, loss: 2.186315
# Epoch 64, loss: 2.155636
# Epoch 65, loss: 2.135428
# Epoch 66, loss: 2.180011
# Epoch 67, loss: 2.173805
# Epoch 68, loss: 2.115311
# Epoch 69, loss: 2.176947
# Epoch 70, loss: 2.203279
# Epoch 71, loss: 2.183021
# Epoch 72, loss: 2.182454
# Epoch 73, loss: 2.132861
# Epoch 74, loss: 2.173479
# Epoch 75, loss: 2.163054
# Epoch 76, loss: 2.180547
# Epoch 77, loss: 2.199321
# Epoch 78, loss: 2.162983
# Epoch 79, loss: 2.190806
# Epoch 80, loss: 2.226634
# Epoch 81, loss: 2.183047
# Epoch 82, loss: 2.206094
# Epoch 83, loss: 2.178680
# Epoch 84, loss: 2.171919
# Epoch 85, loss: 2.161198
# Epoch 86, loss: 2.194586
# Epoch 87, loss: 2.172190
# Epoch 88, loss: 2.177831
# Epoch 89, loss: 2.162626
# Epoch 90, loss: 2.141645
# Epoch 91, loss: 2.187574
# Epoch 92, loss: 2.158848
# Epoch 93, loss: 2.174325
# Epoch 94, loss: 2.182538
# Epoch 95, loss: 2.202164
# Epoch 96, loss: 2.179943
# Epoch 97, loss: 2.207275
# Epoch 98, loss: 2.182690
# Epoch 99, loss: 2.151831
# Accuracy after training for 100 epochs:  0.226
# best validation accuracy achieved: 0.227000

# %% [markdown]
# # Какой же точности мы добились на тестовых данных?

# %%
test_pred = best_classifier.predict(test_X)
test_accuracy = multiclass_accuracy(test_pred, test_y)
print('Linear softmax classifier test set accuracy: %f' % (test_accuracy, ))
# Out:
# Linear softmax classifier test set accuracy: 0.201000
